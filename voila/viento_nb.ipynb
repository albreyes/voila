# %%
# This is a sample Python script.

# Press ⌃R to execute it or replace it with your code.
# Press Double ⇧ to search everywhere for classes, files, tool windows, actions, and settings.
from operaciones import *

#op.ejemplo()

# Parametros generales
data_path = '/Users/pibar/Library/CloudStorage/GoogleDrive-albertoreyesballesteros@gmail.com/Mi unidad/INEEL/AES'
# fileHr = '/datos/VelVientoSept2020-Sept2022_hr.csv'
fileHr = '/datos/datos-20-21-prom-windowgrapher-hr.csv'
# fileDaily = '/datos/VelVientoSept2020-Sept2022_diario.csv'
# fileDaily = '/datos/viento20-22-diarios-validados.csv'
fileDaily = '/datos/datos-20-21-prom-windowgrapher-diarios.csv'

# %%
modelFilename1 = '/modelos/modelStructure.png'
etiquetaEjeY = 'Velocidad de viento m/s'
timestep = 1 # 0-diezminutal 1-horario 2-diario
n_features = 1
num_test = .2  # aquí se está especificando 20% para test
num = 10 # no de casos de prediccion

# %%
datafile = ""

if timestep == 1:  # horario
    datafile = data_path + fileHr
    n_steps_in, n_steps_out = 24, 24
elif timestep == 2:  # diario
    datafile = data_path + fileDaily
    n_steps_in, n_steps_out = 7, 7
op=operaciones()

# %%
raw_seq = op.dataFile2rawSeq(datafile)

# %%
# print(n_steps_in, n_steps_out)
# print('archivo de datos:'+datafile)
type(raw_seq)
#print(raw_seq)
op.grafica_serie(raw_seq,etiquetaEjeY)

# %%
#formatea serie
X, y = op.formatea_serie(raw_seq, n_steps_in, n_steps_out)
#print(X,y)

# %%
# separacion de ejemplos en subconjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test=op.separa_ejemplos(X, y, num_test)
# generacion y archivado del modelo
# modelo = op.genera_modelo(n_steps_in, n_steps_out, n_features, X_train, y_train)
#op.guardar_modelo(modelo, data_path+'/modelos')
#op.ver_modelo(modelo, data_path+modelFilename1)

modelo = op.recupera_modelo(data_path+'/modelos/viento_horario20-22')
# modelo = op.recupera_modelo(data_path+'/modelos/viento_diario20-22/2')

# %%
for _ in range(num):
    op.demo_prediccion(X_test, y_test, n_steps_in, n_features, modelo, etiquetaEjeY)

lista_tplusn = op.lista_predicciones_tplusn(X_test, n_steps_in, n_features, modelo)
print(lista_tplusn)

op.muestra_error(n_steps_out, lista_tplusn, y_test, etiquetaEjeY)
# Out:
# secuencia de entrada: [ 3.539  4.183  4.911  6.083  7.722  8.255  8.944  3.278  1.228  1.789
#   8.022 11.589 11.811 12.744 14.205 14.578 15.072 15.028 13.7   11.255
#  10.439  8.656  7.222  4.933]
# secuencia de salida (predicha): [[ 3.971776   4.4471927  5.578532   6.959017   7.959059   7.5590677
#    6.52055    5.563015   5.1447945  5.5908346  6.3480186  7.628524
#    9.102728  10.613372  11.977632  13.453992  15.034813  15.775664
#   16.4232    16.786322  16.58022   15.786918  14.577639  14.036699 ]]
# secuencia de salida (real): [ 2.605  1.861  2.728  5.711  7.056  2.805  3.222  5.7    5.883  5.439
#   4.961  2.789  1.639  5.056 11.861 14.617 19.889 24.506 26.022 26.816
#  26.339 24.895 22.828 20.994]
# secuencia de entrada: [8.528 9.233 7.145 6.028 5.255 5.7   6.544 6.511 6.044 5.056 4.161 4.378
#  5.444 4.334 3.583 4.561 3.922 3.195 1.95  2.617 3.133 5.389 4.6   2.311]
# secuencia de salida (predicha): [[2.5303857 3.3918633 4.1847887 4.9305706 5.5190268 5.9993057 6.3027678
#   6.1824484 5.5986786 4.8644714 4.1295214 3.5050883 3.0096188 2.7135248
#   2.8538346 3.4723852 4.6015997 5.517139  6.101471  6.5895786 6.786935
#   6.7401705 6.5943174 6.5297933]]
# secuencia de salida (real): [4.789 4.3   4.766 6.072 6.606 7.533 8.    7.278 6.594 6.395 5.611 5.422
#  5.128 5.439 5.067 4.506 5.5   6.878 7.661 7.311 6.194 6.555 7.15  7.75 ]
# secuencia de entrada: [ 5.45   6.267  6.672  6.444  4.972  3.961  4.006  5.456  5.983  5.422
#   6.311  7.739  8.311  9.095 10.328 10.255 10.05  10.139 10.3    9.194
#   8.728  9.778  7.3    7.678]
# secuencia de salida (predicha): [[8.833765  8.71471   8.151338  7.425597  6.659091  6.2966976 6.2144628
#   6.233847  6.2410874 6.605133  7.3234873 8.060524  8.761279  9.191768
#   9.219271  9.041902  8.919371  8.896819  9.044946  9.040546  8.54959
#   7.613415  6.6212916 5.9262934]]
# secuencia de salida (real): [ 7.628  7.45   7.928  6.539  6.867  7.105  7.133  9.678 10.405  9.75
#   9.311  9.155 10.8   11.067 11.3   11.75  11.678 10.855  9.967  8.856
#   8.739  7.933  7.761  7.417]
# secuencia de entrada: [ 8.394  7.745  7.811  7.861  9.428  9.739  9.128  6.628  8.594  8.561
#   9.378  9.644 10.011  9.122  7.328  7.094  6.156  5.806  6.739  7.095
#   7.4    7.411  7.211  6.228]
# secuencia de salida (predicha): [[7.9504414 8.121486  8.4007    8.979859  9.592848  9.848227  9.470669
#   8.739112  7.939181  7.5112553 7.4441648 7.4649863 7.3391914 6.805067
#   6.1353683 5.522621  5.2554293 5.2963223 5.64991   6.1966496 6.4398727
#   6.1286483 5.57084   5.2881618]]
# secuencia de salida (real): [5.878 7.105 7.217 8.394 8.867 8.8   7.589 8.578 8.266 8.022 7.183 6.284
#  6.794 6.694 6.283 5.867 5.467 4.884 4.994 5.722 5.983 5.583 4.739 4.083]
# secuencia de entrada: [ 5.378  7.611  7.195  8.023  7.922  6.328  7.417  6.645  5.972  5.433
#   5.117  4.133  5.017  4.333  3.089  3.739  5.094  4.5    4.167  4.006
#   4.722 11.828 11.922 13.111]
# secuencia de salida (predicha): [[ 9.976851   8.982445   7.686638   6.718766   6.4474244  7.122176
#    8.543558  10.575934  12.187656  12.58298   11.550875   9.742592
#    8.575072   8.575732   9.519055  10.320005  10.083321   8.416452
#    6.220471   4.6852994  4.6013308  5.744463   7.351576   8.98278  ]]
# secuencia de salida (real): [10.6    9.067  8.534  7.961  7.717  6.689  9.828 12.733 14.289 14.561
#  13.972 13.911 12.95  13.156 14.783 14.167 12.561 10.128  7.378  5.35
#   5.917  6.311  9.25   8.328]
# secuencia de entrada: [8.206 7.828 7.561 7.711 7.761 8.205 8.961 9.556 9.345 8.433 8.    8.745
#  8.022 7.345 5.228 3.995 4.3   1.011 0.272 0.65  1.939 3.661 4.584 4.794]
# secuencia de salida (predicha): [[4.5690846 5.252603  5.3020277 4.6911745 3.9110055 3.41148   3.7330232
#   4.620768  5.5292034 6.1880646 6.637936  6.9612575 7.2514424 7.562314
#   7.5641994 7.174511  6.624341  6.1121497 6.2409096 7.1893806 8.325941
#   9.106979  9.411487  9.359751 ]]
# secuencia de salida (real): [3.933 2.078 3.578 4.15  3.356 1.656 2.533 1.522 2.05  1.761 1.044 1.6
#  2.2   5.95  2.033 2.433 1.75  1.655 1.495 2.339 6.323 5.167 6.156 5.806]
# secuencia de entrada: [10.039 10.106  9.061  9.256  8.105  8.956  9.017  8.05   6.922  4.839
#   3.1    1.322  0.844  2.378  3.944  5.983  5.6    6.355  5.567  2.25
#   6.872 15.283 21.422 25.561]
# secuencia de salida (predicha): [[24.537813  24.950085  24.759634  24.33723   23.624352  21.731089
#   19.10848   16.2352    13.569687  11.442004  10.038879   9.050733
#    8.765699   8.874079   8.916983   8.9837265  8.817913   8.020275
#    6.9328322  5.877806   5.1491203  4.9378757  4.7125964  4.6648583]]
# secuencia de salida (real): [29.617 29.089 28.094 27.367 28.339 26.133 23.661 23.133 17.272 12.156
#  10.016  9.322  8.289  8.272 11.3    9.95   6.894  5.35   3.639  1.289
#   0.761  1.228  1.011  1.206]
# secuencia de entrada: [5.639 6.606 7.483 8.15  5.594 6.922 7.189 5.939 6.083 5.622 2.55  2.844
#  5.383 7.167 7.922 8.45  7.128 7.133 7.25  8.1   8.283 7.772 7.545 6.856]
# secuencia de salida (predicha): [[7.978836  8.053866  7.68423   6.9926825 6.215553  5.575164  5.0111237
#   4.5579033 4.455312  4.700777  5.1799726 5.7106924 6.088187  6.181965
#   6.1062946 6.3244963 6.9986563 7.5747833 7.8913245 8.131776  8.405225
#   8.556449  8.759009  8.64807  ]]
# secuencia de salida (real): [6.328 5.411 3.277 2.506 3.644 3.961 3.522 4.744 4.089 4.206 5.372 5.328
#  5.978 6.583 8.789 9.805 8.883 7.533 6.633 6.061 6.072 6.439 5.928 5.75 ]
# secuencia de entrada: [ 8.206 10.017 11.567 13.856 15.75  15.244 18.117 19.355 20.572 22.711
#  22.5   23.044 24.133 21.783 20.811 18.778 18.499 18.828 16.394 16.183
#  14.928 10.894 10.156  9.028]
# secuencia de salida (predicha): [[6.0923243 6.392186  6.685932  6.260563  5.1668353 4.1259174 4.0238843
#   4.810213  5.786989  6.594409  6.6212735 6.0775657 5.3592076 5.0240355
#   5.209532  5.373207  5.200677  4.573613  4.369027  5.0364923 6.133356
#   7.4167886 8.607893  9.278991 ]]
# secuencia de salida (real): [ 6.139  6.544  7.595  6.455  4.445  4.278  4.633  7.756  6.894  6.461
#   6.7    5.839  5.25   5.478  4.289  3.333  3.983  1.911  1.633  2.744
#   5.783  7.75  10.467 11.706]
# secuencia de entrada: [ 0.533  1.294  2.222  5.528  9.766 10.861 13.228 13.456 11.178 15.122
#  19.122 22.589 22.666 22.433 23.156 23.022 23.177 22.883 22.783 21.289
#  21.878 22.411 20.633 20.255]
# secuencia de salida (predicha): [[18.848219  17.97026   17.491617  17.34567   16.40259   14.363277
#   11.873562   9.897617   8.607357   8.024404   7.7225924  7.3277617
#    6.85949    6.9639845  7.7424326  8.463314   9.059985   8.720016
#    7.786447   6.619391   5.300372   3.9218016  2.7849038  2.610334 ]]
# secuencia de salida (real): [20.067 18.094 18.056 16.606 14.339 13.611 11.05   6.478  5.25   5.406
#   5.389  3.678  1.205  3.6    5.222  5.889  5.156  5.417  5.378  5.245
#   4.9    5.295  3.789  3.955]
# [[ 5.83960533  6.02444601  5.93948936 ...  8.24437714  8.23423481
#    8.09057808]
#  [ 6.10460091  5.99945498  6.12540627 ...  6.84699965  6.72176981
#    6.52976561]
#  [ 9.86617756  9.80230904  9.76621342 ...  7.07732105  6.57060528
#    6.34789419]
#  ...
#  [21.28174019 22.28352165 22.47555161 ...  4.59876013  3.79938364
#    3.13140059]
#  [ 6.74010277  7.92687273  9.63216496 ...  6.77015686  5.03774881
#    4.02713776]
#  [ 7.95638943  8.95668221  9.99905014 ... 10.59632301 10.18952084
#    9.94733143]]
# MAPE tiempo t+1: 26.2%
# MAPE tiempo t+2: 23.5%
# MAPE tiempo t+3: 26.9%
# MAPE tiempo t+4: 41.7%
# MAPE tiempo t+5: 27.5%
# MAPE tiempo t+6: 29.3%
# MAPE tiempo t+7: 29.8%
# MAPE tiempo t+8: 31.6%
# MAPE tiempo t+9: 31.9%
# MAPE tiempo t+10: 38.2%
# MAPE tiempo t+11: 31.5%
# MAPE tiempo t+12: 31.1%
# MAPE tiempo t+13: 33.4%
# MAPE tiempo t+14: 45.7%
# MAPE tiempo t+15: 38.9%
# MAPE tiempo t+16: 37.2%
# MAPE tiempo t+17: 30.5%
# MAPE tiempo t+18: 35.1%
# MAPE tiempo t+19: 74.6%
# MAPE tiempo t+20: 33.3%
# MAPE tiempo t+21: 35.3%
# MAPE tiempo t+22: 35.1%
# MAPE tiempo t+23: 37.5%
# MAPE tiempo t+24: 44.9%
